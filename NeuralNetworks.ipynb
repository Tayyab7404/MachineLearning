# %% [markdown]
# # **Neural Networks**

# %% [markdown]
# <center><img src="attachment:7ac70498-26c0-464b-ac2c-5517a19fa4e1.png" width=800 height=800></center>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("NeuralNetworks.csv")

display(data)
# Out:
#    x  y  target
# 0  2  9      92
# 1  1  5      86
# 2  3  6      89

# %%
training = data[["x", "y"]].to_numpy()
target = data["target"].to_numpy()

weights = np.random.uniform(low=-1, high=1, size=(6,))
bias = np.random.uniform(low=-1, high=1, size=(3,))
